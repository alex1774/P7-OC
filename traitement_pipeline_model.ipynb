# %%
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTENC
from imblearn.combine import SMOTETomek
from imblearn.pipeline import Pipeline as imbpipeline
from sklearn import set_config
from analyse_dataset import filling_rate, val_tri
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier
from sklearn.metrics import fbeta_score, make_scorer, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_validate,cross_val_score,cross_val_predict
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler, RobustScaler
from sklearn.linear_model import LogisticRegression,RidgeClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.feature_selection import SelectKBest, f_classif,SelectFpr
from sklearn.svm import LinearSVC

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
set_config(display="diagram", print_changed_only=False)

# %%
data = pd.read_csv('data/application_train.csv',index_col=0)
data.head()
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# 100003                   N             0          270000.0   1293502.5
# 100004                   Y             0           67500.0    135000.0
# 100006                   Y             0          135000.0    312682.5
# 100007                   Y             0          121500.0    513000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE NAME_TYPE_SUITE NAME_INCOME_TYPE  \
# SK_ID_CURR
# 100002          24700.5         351000.0   Unaccompanied          Working
# 100003          35698.5        1129500.0          Family    State servant
# 100004           6750.0         135000.0   Unaccompanied          Working
# 100006          29686.5         297000.0   Unaccompanied          Working
# 100007          21865.5         513000.0   Unaccompanied          Working
#
#                       NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# SK_ID_CURR
# 100002      Secondary / secondary special  Single / not married
# 100003                   Higher education               Married
# 100004      Secondary / secondary special  Single / not married
# 100006      Secondary / secondary special        Civil marriage
# 100007      Secondary / secondary special  Single / not married
#
#             NAME_HOUSING_TYPE  REGION_POPULATION_RELATIVE  DAYS_BIRTH  \
# SK_ID_CURR
# 100002      House / apartment                    0.018801       -9461
# 100003      House / apartment                    0.003541      -16765
# 100004      House / apartment                    0.010032      -19046
# 100006      House / apartment                    0.008019      -19005
# 100007      House / apartment                    0.028663      -19932
#
#             DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  \
# SK_ID_CURR
# 100002               -637            -3648.0            -2120          NaN
# 100003              -1188            -1186.0             -291          NaN
# 100004               -225            -4260.0            -2531         26.0
# 100006              -3039            -9833.0            -2437          NaN
# 100007              -3038            -4311.0            -3458          NaN
#
#             FLAG_MOBIL  FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  \
# SK_ID_CURR
# 100002               1               1                0                 1
# 100003               1               1                0                 1
# 100004               1               1                1                 1
# 100006               1               1                0                 1
# 100007               1               1                0                 1
#
#             FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# SK_ID_CURR
# 100002               1           0        Laborers              1.0
# 100003               1           0      Core staff              2.0
# 100004               1           0        Laborers              1.0
# 100006               0           0        Laborers              2.0
# 100007               0           0      Core staff              1.0
#
#             REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# SK_ID_CURR
# 100002                         2                            2
# 100003                         1                            1
# 100004                         2                            2
# 100006                         2                            2
# 100007                         2                            2
#
#            WEEKDAY_APPR_PROCESS_START  HOUR_APPR_PROCESS_START  \
# SK_ID_CURR
# 100002                      WEDNESDAY                       10
# 100003                         MONDAY                       11
# 100004                         MONDAY                        9
# 100006                      WEDNESDAY                       17
# 100007                       THURSDAY                       11
#
#             REG_REGION_NOT_LIVE_REGION  REG_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100002                               0                           0
# 100003                               0                           0
# 100004                               0                           0
# 100006                               0                           0
# 100007                               0                           0
#
#             LIVE_REGION_NOT_WORK_REGION  REG_CITY_NOT_LIVE_CITY  \
# SK_ID_CURR
# 100002                                0                       0
# 100003                                0                       0
# 100004                                0                       0
# 100006                                0                       0
# 100007                                0                       0
#
#             REG_CITY_NOT_WORK_CITY  LIVE_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100002                           0                        0
# 100003                           0                        0
# 100004                           0                        0
# 100006                           0                        0
# 100007                           1                        1
#
#                  ORGANIZATION_TYPE  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  \
# SK_ID_CURR
# 100002      Business Entity Type 3      0.083037      0.262949      0.139376
# 100003                      School      0.311267      0.622246           NaN
# 100004                  Government           NaN      0.555912      0.729567
# 100006      Business Entity Type 3           NaN      0.650442           NaN
# 100007                    Religion           NaN      0.322738           NaN
#
#             APARTMENTS_AVG  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# SK_ID_CURR
# 100002              0.0247            0.0369                       0.9722
# 100003              0.0959            0.0529                       0.9851
# 100004                 NaN               NaN                          NaN
# 100006                 NaN               NaN                          NaN
# 100007                 NaN               NaN                          NaN
#
#             YEARS_BUILD_AVG  COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  \
# SK_ID_CURR
# 100002               0.6192          0.0143           0.00         0.0690
# 100003               0.7960          0.0605           0.08         0.0345
# 100004                  NaN             NaN            NaN            NaN
# 100006                  NaN             NaN            NaN            NaN
# 100007                  NaN             NaN            NaN            NaN
#
#             FLOORSMAX_AVG  FLOORSMIN_AVG  LANDAREA_AVG  LIVINGAPARTMENTS_AVG  \
# SK_ID_CURR
# 100002             0.0833         0.1250        0.0369                0.0202
# 100003             0.2917         0.3333        0.0130                0.0773
# 100004                NaN            NaN           NaN                   NaN
# 100006                NaN            NaN           NaN                   NaN
# 100007                NaN            NaN           NaN                   NaN
#
#             LIVINGAREA_AVG  NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  \
# SK_ID_CURR
# 100002              0.0190                   0.0000             0.0000
# 100003              0.0549                   0.0039             0.0098
# 100004                 NaN                      NaN                NaN
# 100006                 NaN                      NaN                NaN
# 100007                 NaN                      NaN                NaN
#
#             APARTMENTS_MODE  BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  \
# SK_ID_CURR
# 100002               0.0252             0.0383                        0.9722
# 100003               0.0924             0.0538                        0.9851
# 100004                  NaN                NaN                           NaN
# 100006                  NaN                NaN                           NaN
# 100007                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MODE  COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  \
# SK_ID_CURR
# 100002                0.6341           0.0144          0.0000          0.0690
# 100003                0.8040           0.0497          0.0806          0.0345
# 100004                   NaN              NaN             NaN             NaN
# 100006                   NaN              NaN             NaN             NaN
# 100007                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MODE  FLOORSMIN_MODE  LANDAREA_MODE  \
# SK_ID_CURR
# 100002              0.0833          0.1250         0.0377
# 100003              0.2917          0.3333         0.0128
# 100004                 NaN             NaN            NaN
# 100006                 NaN             NaN            NaN
# 100007                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MODE  LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100002                      0.022           0.0198                       0.0
# 100003                      0.079           0.0554                       0.0
# 100004                        NaN              NaN                       NaN
# 100006                        NaN              NaN                       NaN
# 100007                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MODE  APARTMENTS_MEDI  BASEMENTAREA_MEDI  \
# SK_ID_CURR
# 100002                     0.0           0.0250             0.0369
# 100003                     0.0           0.0968             0.0529
# 100004                     NaN              NaN                NaN
# 100006                     NaN              NaN                NaN
# 100007                     NaN              NaN                NaN
#
#             YEARS_BEGINEXPLUATATION_MEDI  YEARS_BUILD_MEDI  COMMONAREA_MEDI  \
# SK_ID_CURR
# 100002                            0.9722            0.6243           0.0144
# 100003                            0.9851            0.7987           0.0608
# 100004                               NaN               NaN              NaN
# 100006                               NaN               NaN              NaN
# 100007                               NaN               NaN              NaN
#
#             ELEVATORS_MEDI  ENTRANCES_MEDI  FLOORSMAX_MEDI  FLOORSMIN_MEDI  \
# SK_ID_CURR
# 100002                0.00          0.0690          0.0833          0.1250
# 100003                0.08          0.0345          0.2917          0.3333
# 100004                 NaN             NaN             NaN             NaN
# 100006                 NaN             NaN             NaN             NaN
# 100007                 NaN             NaN             NaN             NaN
#
#             LANDAREA_MEDI  LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  \
# SK_ID_CURR
# 100002             0.0375                 0.0205           0.0193
# 100003             0.0132                 0.0787           0.0558
# 100004                NaN                    NaN              NaN
# 100006                NaN                    NaN              NaN
# 100007                NaN                    NaN              NaN
#
#             NONLIVINGAPARTMENTS_MEDI  NONLIVINGAREA_MEDI FONDKAPREMONT_MODE  \
# SK_ID_CURR
# 100002                        0.0000                0.00   reg oper account
# 100003                        0.0039                0.01   reg oper account
# 100004                           NaN                 NaN                NaN
# 100006                           NaN                 NaN                NaN
# 100007                           NaN                 NaN                NaN
#
#             HOUSETYPE_MODE  TOTALAREA_MODE WALLSMATERIAL_MODE  \
# SK_ID_CURR
# 100002      block of flats          0.0149       Stone, brick
# 100003      block of flats          0.0714              Block
# 100004                 NaN             NaN                NaN
# 100006                 NaN             NaN                NaN
# 100007                 NaN             NaN                NaN
#
#            EMERGENCYSTATE_MODE  OBS_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                      No                       2.0
# 100003                      No                       1.0
# 100004                     NaN                       0.0
# 100006                     NaN                       2.0
# 100007                     NaN                       0.0
#
#             DEF_30_CNT_SOCIAL_CIRCLE  OBS_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100003                           0.0                       1.0
# 100004                           0.0                       0.0
# 100006                           0.0                       2.0
# 100007                           0.0                       0.0
#
#             DEF_60_CNT_SOCIAL_CIRCLE  DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  \
# SK_ID_CURR
# 100002                           2.0                 -1134.0                0
# 100003                           0.0                  -828.0                0
# 100004                           0.0                  -815.0                0
# 100006                           0.0                  -617.0                0
# 100007                           0.0                 -1106.0                0
#
#             FLAG_DOCUMENT_3  FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  \
# SK_ID_CURR
# 100002                    1                0                0
# 100003                    1                0                0
# 100004                    0                0                0
# 100006                    1                0                0
# 100007                    0                0                0
#
#             FLAG_DOCUMENT_6  FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  \
# SK_ID_CURR
# 100002                    0                0                0
# 100003                    0                0                0
# 100004                    0                0                0
# 100006                    0                0                0
# 100007                    0                0                1
#
#             FLAG_DOCUMENT_9  FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  \
# SK_ID_CURR
# 100002                    0                 0                 0
# 100003                    0                 0                 0
# 100004                    0                 0                 0
# 100006                    0                 0                 0
# 100007                    0                 0                 0
#
#             FLAG_DOCUMENT_12  FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_15  FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_18  FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  \
# SK_ID_CURR
# 100002                     0                 0                 0
# 100003                     0                 0                 0
# 100004                     0                 0                 0
# 100006                     0                 0                 0
# 100007                     0                 0                 0
#
#             FLAG_DOCUMENT_21  AMT_REQ_CREDIT_BUREAU_HOUR  \
# SK_ID_CURR
# 100002                     0                         0.0
# 100003                     0                         0.0
# 100004                     0                         0.0
# 100006                     0                         NaN
# 100007                     0                         0.0
#
#             AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# SK_ID_CURR
# 100002                            0.0                         0.0
# 100003                            0.0                         0.0
# 100004                            0.0                         0.0
# 100006                            NaN                         NaN
# 100007                            0.0                         0.0
#
#             AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# SK_ID_CURR
# 100002                            0.0                        0.0
# 100003                            0.0                        0.0
# 100004                            0.0                        0.0
# 100006                            NaN                        NaN
# 100007                            0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_CURR
# 100002                             1.0
# 100003                             0.0
# 100004                             0.0
# 100006                             NaN
# 100007                             0.0

# %%
filling_rate(data)
# Out:
#              no                                 variable name    data not NaN             type    Filling Rate  %
#               0                                        TARGET          307511            int64        100.0000 %
#               1                            NAME_CONTRACT_TYPE          307511           object        100.0000 %
#               2                                   CODE_GENDER          307511           object        100.0000 %
#               3                                  FLAG_OWN_CAR          307511           object        100.0000 %
#               4                               FLAG_OWN_REALTY          307511           object        100.0000 %
#               5                                  CNT_CHILDREN          307511            int64        100.0000 %
#               6                              AMT_INCOME_TOTAL          307511          float64        100.0000 %
#               7                                    AMT_CREDIT          307511          float64        100.0000 %
#               8                                   AMT_ANNUITY          307499          float64         99.9961 %
#               9                               AMT_GOODS_PRICE          307233          float64         99.9096 %
#              10                               NAME_TYPE_SUITE          306219           object         99.5799 %
#              11                              NAME_INCOME_TYPE          307511           object        100.0000 %
#              12                           NAME_EDUCATION_TYPE          307511           object        100.0000 %
#              13                            NAME_FAMILY_STATUS          307511           object        100.0000 %
#              14                             NAME_HOUSING_TYPE          307511           object        100.0000 %
#              15                    REGION_POPULATION_RELATIVE          307511          float64        100.0000 %
#              16                                    DAYS_BIRTH          307511            int64        100.0000 %
#              17                                 DAYS_EMPLOYED          307511            int64        100.0000 %
#              18                             DAYS_REGISTRATION          307511          float64        100.0000 %
#              19                               DAYS_ID_PUBLISH          307511            int64        100.0000 %
#              20                                   OWN_CAR_AGE          104582          float64         34.0092 %
#              21                                    FLAG_MOBIL          307511            int64        100.0000 %
#              22                                FLAG_EMP_PHONE          307511            int64        100.0000 %
#              23                               FLAG_WORK_PHONE          307511            int64        100.0000 %
#              24                              FLAG_CONT_MOBILE          307511            int64        100.0000 %
#              25                                    FLAG_PHONE          307511            int64        100.0000 %
#              26                                    FLAG_EMAIL          307511            int64        100.0000 %
#              27                               OCCUPATION_TYPE          211120           object         68.6545 %
#              28                               CNT_FAM_MEMBERS          307509          float64         99.9993 %
#              29                          REGION_RATING_CLIENT          307511            int64        100.0000 %
#              30                   REGION_RATING_CLIENT_W_CITY          307511            int64        100.0000 %
#              31                    WEEKDAY_APPR_PROCESS_START          307511           object        100.0000 %
#              32                       HOUR_APPR_PROCESS_START          307511            int64        100.0000 %
#              33                    REG_REGION_NOT_LIVE_REGION          307511            int64        100.0000 %
#              34                    REG_REGION_NOT_WORK_REGION          307511            int64        100.0000 %
#              35                   LIVE_REGION_NOT_WORK_REGION          307511            int64        100.0000 %
#              36                        REG_CITY_NOT_LIVE_CITY          307511            int64        100.0000 %
#              37                        REG_CITY_NOT_WORK_CITY          307511            int64        100.0000 %
#              38                       LIVE_CITY_NOT_WORK_CITY          307511            int64        100.0000 %
#              39                             ORGANIZATION_TYPE          307511           object        100.0000 %
#              40                                  EXT_SOURCE_1          134133          float64         43.6189 %
#              41                                  EXT_SOURCE_2          306851          float64         99.7854 %
#              42                                  EXT_SOURCE_3          246546          float64         80.1747 %
#              43                                APARTMENTS_AVG          151450          float64         49.2503 %
#              44                              BASEMENTAREA_AVG          127568          float64         41.4840 %
#              45                   YEARS_BEGINEXPLUATATION_AVG          157504          float64         51.2190 %
#              46                               YEARS_BUILD_AVG          103023          float64         33.5022 %
#              47                                COMMONAREA_AVG           92646          float64         30.1277 %
#              48                                 ELEVATORS_AVG          143620          float64         46.7040 %
#              49                                 ENTRANCES_AVG          152683          float64         49.6512 %
#              50                                 FLOORSMAX_AVG          154491          float64         50.2392 %
#              51                                 FLOORSMIN_AVG           98869          float64         32.1514 %
#              52                                  LANDAREA_AVG          124921          float64         40.6233 %
#              53                          LIVINGAPARTMENTS_AVG           97312          float64         31.6450 %
#              54                                LIVINGAREA_AVG          153161          float64         49.8067 %
#              55                       NONLIVINGAPARTMENTS_AVG           93997          float64         30.5670 %
#              56                             NONLIVINGAREA_AVG          137829          float64         44.8208 %
#              57                               APARTMENTS_MODE          151450          float64         49.2503 %
#              58                             BASEMENTAREA_MODE          127568          float64         41.4840 %
#              59                  YEARS_BEGINEXPLUATATION_MODE          157504          float64         51.2190 %
#              60                              YEARS_BUILD_MODE          103023          float64         33.5022 %
#              61                               COMMONAREA_MODE           92646          float64         30.1277 %
#              62                                ELEVATORS_MODE          143620          float64         46.7040 %
#              63                                ENTRANCES_MODE          152683          float64         49.6512 %
#              64                                FLOORSMAX_MODE          154491          float64         50.2392 %
#              65                                FLOORSMIN_MODE           98869          float64         32.1514 %
#              66                                 LANDAREA_MODE          124921          float64         40.6233 %
#              67                         LIVINGAPARTMENTS_MODE           97312          float64         31.6450 %
#              68                               LIVINGAREA_MODE          153161          float64         49.8067 %
#              69                      NONLIVINGAPARTMENTS_MODE           93997          float64         30.5670 %
#              70                            NONLIVINGAREA_MODE          137829          float64         44.8208 %
#              71                               APARTMENTS_MEDI          151450          float64         49.2503 %
#              72                             BASEMENTAREA_MEDI          127568          float64         41.4840 %
#              73                  YEARS_BEGINEXPLUATATION_MEDI          157504          float64         51.2190 %
#              74                              YEARS_BUILD_MEDI          103023          float64         33.5022 %
#              75                               COMMONAREA_MEDI           92646          float64         30.1277 %
#              76                                ELEVATORS_MEDI          143620          float64         46.7040 %
#              77                                ENTRANCES_MEDI          152683          float64         49.6512 %
#              78                                FLOORSMAX_MEDI          154491          float64         50.2392 %
#              79                                FLOORSMIN_MEDI           98869          float64         32.1514 %
#              80                                 LANDAREA_MEDI          124921          float64         40.6233 %
#              81                         LIVINGAPARTMENTS_MEDI           97312          float64         31.6450 %
#              82                               LIVINGAREA_MEDI          153161          float64         49.8067 %
#              83                      NONLIVINGAPARTMENTS_MEDI           93997          float64         30.5670 %
#              84                            NONLIVINGAREA_MEDI          137829          float64         44.8208 %
#              85                            FONDKAPREMONT_MODE           97216           object         31.6138 %
#              86                                HOUSETYPE_MODE          153214           object         49.8239 %
#              87                                TOTALAREA_MODE          159080          float64         51.7315 %
#              88                            WALLSMATERIAL_MODE          151170           object         49.1592 %
#              89                           EMERGENCYSTATE_MODE          161756           object         52.6017 %
#              90                      OBS_30_CNT_SOCIAL_CIRCLE          306490          float64         99.6680 %
#              91                      DEF_30_CNT_SOCIAL_CIRCLE          306490          float64         99.6680 %
#              92                      OBS_60_CNT_SOCIAL_CIRCLE          306490          float64         99.6680 %
#              93                      DEF_60_CNT_SOCIAL_CIRCLE          306490          float64         99.6680 %
#              94                        DAYS_LAST_PHONE_CHANGE          307510          float64         99.9997 %
#              95                               FLAG_DOCUMENT_2          307511            int64        100.0000 %
#              96                               FLAG_DOCUMENT_3          307511            int64        100.0000 %
#              97                               FLAG_DOCUMENT_4          307511            int64        100.0000 %
#              98                               FLAG_DOCUMENT_5          307511            int64        100.0000 %
#              99                               FLAG_DOCUMENT_6          307511            int64        100.0000 %
#             100                               FLAG_DOCUMENT_7          307511            int64        100.0000 %
#             101                               FLAG_DOCUMENT_8          307511            int64        100.0000 %
#             102                               FLAG_DOCUMENT_9          307511            int64        100.0000 %
#             103                              FLAG_DOCUMENT_10          307511            int64        100.0000 %
#             104                              FLAG_DOCUMENT_11          307511            int64        100.0000 %
#             105                              FLAG_DOCUMENT_12          307511            int64        100.0000 %
#             106                              FLAG_DOCUMENT_13          307511            int64        100.0000 %
#             107                              FLAG_DOCUMENT_14          307511            int64        100.0000 %
#             108                              FLAG_DOCUMENT_15          307511            int64        100.0000 %
#             109                              FLAG_DOCUMENT_16          307511            int64        100.0000 %
#             110                              FLAG_DOCUMENT_17          307511            int64        100.0000 %
#             111                              FLAG_DOCUMENT_18          307511            int64        100.0000 %
#             112                              FLAG_DOCUMENT_19          307511            int64        100.0000 %
#             113                              FLAG_DOCUMENT_20          307511            int64        100.0000 %
#             114                              FLAG_DOCUMENT_21          307511            int64        100.0000 %
#             115                    AMT_REQ_CREDIT_BUREAU_HOUR          265992          float64         86.4984 %
#             116                     AMT_REQ_CREDIT_BUREAU_DAY          265992          float64         86.4984 %
#             117                    AMT_REQ_CREDIT_BUREAU_WEEK          265992          float64         86.4984 %
#             118                     AMT_REQ_CREDIT_BUREAU_MON          265992          float64         86.4984 %
#             119                     AMT_REQ_CREDIT_BUREAU_QRT          265992          float64         86.4984 %
#             120                    AMT_REQ_CREDIT_BUREAU_YEAR          265992          float64         86.4984 %

# %%
def col_to_bool(dataf):
    liste_col=[]
    for i in range(0, len(dataf.columns)):
        if (dataf.iloc[:,i].dtypes == 'int64') & (len(dataf.iloc[:,i].value_counts())==2):
            liste_col.append(i)
    return(liste_col)

# %%
def visu_col_to_bool (dataf, liste):
    for i in liste:
        print(i, ' ',dataf.columns[i])
        display(dataf[dataf.columns[i]].value_counts())
        print()

# %%
visu_col_to_bool(data,col_to_bool(data) )
# Out:
# 0   TARGET
# 0    282686
# 1     24825
# Name: TARGET, dtype: int64
# 21   FLAG_MOBIL
# 1    307510
# 0         1
# Name: FLAG_MOBIL, dtype: int64
# 22   FLAG_EMP_PHONE
# 1    252125
# 0     55386
# Name: FLAG_EMP_PHONE, dtype: int64
# 23   FLAG_WORK_PHONE
# 0    246203
# 1     61308
# Name: FLAG_WORK_PHONE, dtype: int64
# 24   FLAG_CONT_MOBILE
# 1    306937
# 0       574
# Name: FLAG_CONT_MOBILE, dtype: int64
# 25   FLAG_PHONE
# 0    221080
# 1     86431
# Name: FLAG_PHONE, dtype: int64
# 26   FLAG_EMAIL
# 0    290069
# 1     17442
# Name: FLAG_EMAIL, dtype: int64
# 33   REG_REGION_NOT_LIVE_REGION
# 0    302854
# 1      4657
# Name: REG_REGION_NOT_LIVE_REGION, dtype: int64
# 34   REG_REGION_NOT_WORK_REGION
# 0    291899
# 1     15612
# Name: REG_REGION_NOT_WORK_REGION, dtype: int64
# 35   LIVE_REGION_NOT_WORK_REGION
# 0    295008
# 1     12503
# Name: LIVE_REGION_NOT_WORK_REGION, dtype: int64
# 36   REG_CITY_NOT_LIVE_CITY
# 0    283472
# 1     24039
# Name: REG_CITY_NOT_LIVE_CITY, dtype: int64
# 37   REG_CITY_NOT_WORK_CITY
# 0    236644
# 1     70867
# Name: REG_CITY_NOT_WORK_CITY, dtype: int64
# 38   LIVE_CITY_NOT_WORK_CITY
# 0    252296
# 1     55215
# Name: LIVE_CITY_NOT_WORK_CITY, dtype: int64
# 95   FLAG_DOCUMENT_2
# 0    307498
# 1        13
# Name: FLAG_DOCUMENT_2, dtype: int64
# 96   FLAG_DOCUMENT_3
# 1    218340
# 0     89171
# Name: FLAG_DOCUMENT_3, dtype: int64
# 97   FLAG_DOCUMENT_4
# 0    307486
# 1        25
# Name: FLAG_DOCUMENT_4, dtype: int64
# 98   FLAG_DOCUMENT_5
# 0    302863
# 1      4648
# Name: FLAG_DOCUMENT_5, dtype: int64
# 99   FLAG_DOCUMENT_6
# 0    280433
# 1     27078
# Name: FLAG_DOCUMENT_6, dtype: int64
# 100   FLAG_DOCUMENT_7
# 0    307452
# 1        59
# Name: FLAG_DOCUMENT_7, dtype: int64
# 101   FLAG_DOCUMENT_8
# 0    282487
# 1     25024
# Name: FLAG_DOCUMENT_8, dtype: int64
# 102   FLAG_DOCUMENT_9
# 0    306313
# 1      1198
# Name: FLAG_DOCUMENT_9, dtype: int64
# 103   FLAG_DOCUMENT_10
# 0    307504
# 1         7
# Name: FLAG_DOCUMENT_10, dtype: int64
# 104   FLAG_DOCUMENT_11
# 0    306308
# 1      1203
# Name: FLAG_DOCUMENT_11, dtype: int64
# 105   FLAG_DOCUMENT_12
# 0    307509
# 1         2
# Name: FLAG_DOCUMENT_12, dtype: int64
# 106   FLAG_DOCUMENT_13
# 0    306427
# 1      1084
# Name: FLAG_DOCUMENT_13, dtype: int64
# 107   FLAG_DOCUMENT_14
# 0    306608
# 1       903
# Name: FLAG_DOCUMENT_14, dtype: int64
# 108   FLAG_DOCUMENT_15
# 0    307139
# 1       372
# Name: FLAG_DOCUMENT_15, dtype: int64
# 109   FLAG_DOCUMENT_16
# 0    304458
# 1      3053
# Name: FLAG_DOCUMENT_16, dtype: int64
# 110   FLAG_DOCUMENT_17
# 0    307429
# 1        82
# Name: FLAG_DOCUMENT_17, dtype: int64
# 111   FLAG_DOCUMENT_18
# 0    305011
# 1      2500
# Name: FLAG_DOCUMENT_18, dtype: int64
# 112   FLAG_DOCUMENT_19
# 0    307328
# 1       183
# Name: FLAG_DOCUMENT_19, dtype: int64
# 113   FLAG_DOCUMENT_20
# 0    307355
# 1       156
# Name: FLAG_DOCUMENT_20, dtype: int64
# 114   FLAG_DOCUMENT_21
# 0    307408
# 1       103
# Name: FLAG_DOCUMENT_21, dtype: int64

# %%
data.iloc[:,col_to_bool(data)]=data.iloc[:,col_to_bool(data)].astype('bool',copy=False)

# %%
filling_rate(data)
# Out:
#              no                                 variable name    data not NaN             type    Filling Rate  %
#               0                                        TARGET          307511             bool        100.0000 %
#               1                            NAME_CONTRACT_TYPE          307511           object        100.0000 %
#               2                                   CODE_GENDER          307511           object        100.0000 %
#               3                                  FLAG_OWN_CAR          307511           object        100.0000 %
#               4                               FLAG_OWN_REALTY          307511           object        100.0000 %
#               5                                  CNT_CHILDREN          307511            int64        100.0000 %
#               6                              AMT_INCOME_TOTAL          307511          float64        100.0000 %
#               7                                    AMT_CREDIT          307511          float64        100.0000 %
#               8                                   AMT_ANNUITY          307499          float64         99.9961 %
#               9                               AMT_GOODS_PRICE          307233          float64         99.9096 %
#              10                               NAME_TYPE_SUITE          306219           object         99.5799 %
#              11                              NAME_INCOME_TYPE          307511           object        100.0000 %
#              12                           NAME_EDUCATION_TYPE          307511           object        100.0000 %
#              13                            NAME_FAMILY_STATUS          307511           object        100.0000 %
#              14                             NAME_HOUSING_TYPE          307511           object        100.0000 %
#              15                    REGION_POPULATION_RELATIVE          307511          float64        100.0000 %
#              16                                    DAYS_BIRTH          307511            int64        100.0000 %
#              17                                 DAYS_EMPLOYED          307511            int64        100.0000 %
#              18                             DAYS_REGISTRATION          307511          float64        100.0000 %
#              19                               DAYS_ID_PUBLISH          307511            int64        100.0000 %
#              20                                   OWN_CAR_AGE          104582          float64         34.0092 %
#              21                                    FLAG_MOBIL          307511             bool        100.0000 %
#              22                                FLAG_EMP_PHONE          307511             bool        100.0000 %
#              23                               FLAG_WORK_PHONE          307511             bool        100.0000 %
#              24                              FLAG_CONT_MOBILE          307511             bool        100.0000 %
#              25                                    FLAG_PHONE          307511             bool        100.0000 %
#              26                                    FLAG_EMAIL          307511             bool        100.0000 %
#              27                               OCCUPATION_TYPE          211120           object         68.6545 %
#              28                               CNT_FAM_MEMBERS          307509          float64         99.9993 %
#              29                          REGION_RATING_CLIENT          307511            int64        100.0000 %
#              30                   REGION_RATING_CLIENT_W_CITY          307511            int64        100.0000 %
#              31                    WEEKDAY_APPR_PROCESS_START          307511           object        100.0000 %
#              32                       HOUR_APPR_PROCESS_START          307511            int64        100.0000 %
#              33                    REG_REGION_NOT_LIVE_REGION          307511             bool        100.0000 %
#              34                    REG_REGION_NOT_WORK_REGION          307511             bool        100.0000 %
#              35                   LIVE_REGION_NOT_WORK_REGION          307511             bool        100.0000 %
#              36                        REG_CITY_NOT_LIVE_CITY          307511             bool        100.0000 %
#              37                        REG_CITY_NOT_WORK_CITY          307511             bool        100.0000 %
#              38                       LIVE_CITY_NOT_WORK_CITY          307511             bool        100.0000 %
#              39                             ORGANIZATION_TYPE          307511           object        100.0000 %
#              40                                  EXT_SOURCE_1          134133          float64         43.6189 %
#              41                                  EXT_SOURCE_2          306851          float64         99.7854 %
#              42                                  EXT_SOURCE_3          246546          float64         80.1747 %
#              43                                APARTMENTS_AVG          151450          float64         49.2503 %
#              44                              BASEMENTAREA_AVG          127568          float64         41.4840 %
#              45                   YEARS_BEGINEXPLUATATION_AVG          157504          float64         51.2190 %
#              46                               YEARS_BUILD_AVG          103023          float64         33.5022 %
#              47                                COMMONAREA_AVG           92646          float64         30.1277 %
#              48                                 ELEVATORS_AVG          143620          float64         46.7040 %
#              49                                 ENTRANCES_AVG          152683          float64         49.6512 %
#              50                                 FLOORSMAX_AVG          154491          float64         50.2392 %
#              51                                 FLOORSMIN_AVG           98869          float64         32.1514 %
#              52                                  LANDAREA_AVG          124921          float64         40.6233 %
#              53                          LIVINGAPARTMENTS_AVG           97312          float64         31.6450 %
#              54                                LIVINGAREA_AVG          153161          float64         49.8067 %
#              55                       NONLIVINGAPARTMENTS_AVG           93997          float64         30.5670 %
#              56                             NONLIVINGAREA_AVG          137829          float64         44.8208 %
#              57                               APARTMENTS_MODE          151450          float64         49.2503 %
#              58                             BASEMENTAREA_MODE          127568          float64         41.4840 %
#              59                  YEARS_BEGINEXPLUATATION_MODE          157504          float64         51.2190 %
#              60                              YEARS_BUILD_MODE          103023          float64         33.5022 %
#              61                               COMMONAREA_MODE           92646          float64         30.1277 %
#              62                                ELEVATORS_MODE          143620          float64         46.7040 %
#              63                                ENTRANCES_MODE          152683          float64         49.6512 %
#              64                                FLOORSMAX_MODE          154491          float64         50.2392 %
#              65                                FLOORSMIN_MODE           98869          float64         32.1514 %
#              66                                 LANDAREA_MODE          124921          float64         40.6233 %
#              67                         LIVINGAPARTMENTS_MODE           97312          float64         31.6450 %
#              68                               LIVINGAREA_MODE          153161          float64         49.8067 %
#              69                      NONLIVINGAPARTMENTS_MODE           93997          float64         30.5670 %
#              70                            NONLIVINGAREA_MODE          137829          float64         44.8208 %
#              71                               APARTMENTS_MEDI          151450          float64         49.2503 %
#              72                             BASEMENTAREA_MEDI          127568          float64         41.4840 %
#              73                  YEARS_BEGINEXPLUATATION_MEDI          157504          float64         51.2190 %
#              74                              YEARS_BUILD_MEDI          103023          float64         33.5022 %
#              75                               COMMONAREA_MEDI           92646          float64         30.1277 %
#              76                                ELEVATORS_MEDI          143620          float64         46.7040 %
#              77                                ENTRANCES_MEDI          152683          float64         49.6512 %
#              78                                FLOORSMAX_MEDI          154491          float64         50.2392 %
#              79                                FLOORSMIN_MEDI           98869          float64         32.1514 %
#              80                                 LANDAREA_MEDI          124921          float64         40.6233 %
#              81                         LIVINGAPARTMENTS_MEDI           97312          float64         31.6450 %
#              82                               LIVINGAREA_MEDI          153161          float64         49.8067 %
#              83                      NONLIVINGAPARTMENTS_MEDI           93997          float64         30.5670 %
#              84                            NONLIVINGAREA_MEDI          137829          float64         44.8208 %
#              85                            FONDKAPREMONT_MODE           97216           object         31.6138 %
#              86                                HOUSETYPE_MODE          153214           object         49.8239 %
#              87                                TOTALAREA_MODE          159080          float64         51.7315 %
#              88                            WALLSMATERIAL_MODE          151170           object         49.1592 %
#              89                           EMERGENCYSTATE_MODE          161756           object         52.6017 %
#              90                      OBS_30_CNT_SOCIAL_CIRCLE          306490          float64         99.6680 %
#              91                      DEF_30_CNT_SOCIAL_CIRCLE          306490          float64         99.6680 %
#              92                      OBS_60_CNT_SOCIAL_CIRCLE          306490          float64         99.6680 %
#              93                      DEF_60_CNT_SOCIAL_CIRCLE          306490          float64         99.6680 %
#              94                        DAYS_LAST_PHONE_CHANGE          307510          float64         99.9997 %
#              95                               FLAG_DOCUMENT_2          307511             bool        100.0000 %
#              96                               FLAG_DOCUMENT_3          307511             bool        100.0000 %
#              97                               FLAG_DOCUMENT_4          307511             bool        100.0000 %
#              98                               FLAG_DOCUMENT_5          307511             bool        100.0000 %
#              99                               FLAG_DOCUMENT_6          307511             bool        100.0000 %
#             100                               FLAG_DOCUMENT_7          307511             bool        100.0000 %
#             101                               FLAG_DOCUMENT_8          307511             bool        100.0000 %
#             102                               FLAG_DOCUMENT_9          307511             bool        100.0000 %
#             103                              FLAG_DOCUMENT_10          307511             bool        100.0000 %
#             104                              FLAG_DOCUMENT_11          307511             bool        100.0000 %
#             105                              FLAG_DOCUMENT_12          307511             bool        100.0000 %
#             106                              FLAG_DOCUMENT_13          307511             bool        100.0000 %
#             107                              FLAG_DOCUMENT_14          307511             bool        100.0000 %
#             108                              FLAG_DOCUMENT_15          307511             bool        100.0000 %
#             109                              FLAG_DOCUMENT_16          307511             bool        100.0000 %
#             110                              FLAG_DOCUMENT_17          307511             bool        100.0000 %
#             111                              FLAG_DOCUMENT_18          307511             bool        100.0000 %
#             112                              FLAG_DOCUMENT_19          307511             bool        100.0000 %
#             113                              FLAG_DOCUMENT_20          307511             bool        100.0000 %
#             114                              FLAG_DOCUMENT_21          307511             bool        100.0000 %
#             115                    AMT_REQ_CREDIT_BUREAU_HOUR          265992          float64         86.4984 %
#             116                     AMT_REQ_CREDIT_BUREAU_DAY          265992          float64         86.4984 %
#             117                    AMT_REQ_CREDIT_BUREAU_WEEK          265992          float64         86.4984 %
#             118                     AMT_REQ_CREDIT_BUREAU_MON          265992          float64         86.4984 %
#             119                     AMT_REQ_CREDIT_BUREAU_QRT          265992          float64         86.4984 %
#             120                    AMT_REQ_CREDIT_BUREAU_YEAR          265992          float64         86.4984 %

# %%
data.describe()
# Out:
#         CNT_CHILDREN  AMT_INCOME_TOTAL    AMT_CREDIT    AMT_ANNUITY  \
# count  307511.000000      3.075110e+05  3.075110e+05  307499.000000
# mean        0.417052      1.687979e+05  5.990260e+05   27108.573909
# std         0.722121      2.371231e+05  4.024908e+05   14493.737315
# min         0.000000      2.565000e+04  4.500000e+04    1615.500000
# 25%         0.000000      1.125000e+05  2.700000e+05   16524.000000
# 50%         0.000000      1.471500e+05  5.135310e+05   24903.000000
# 75%         1.000000      2.025000e+05  8.086500e+05   34596.000000
# max        19.000000      1.170000e+08  4.050000e+06  258025.500000
#
#        AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE     DAYS_BIRTH  \
# count     3.072330e+05               307511.000000  307511.000000
# mean      5.383962e+05                    0.020868  -16036.995067
# std       3.694465e+05                    0.013831    4363.988632
# min       4.050000e+04                    0.000290  -25229.000000
# 25%       2.385000e+05                    0.010006  -19682.000000
# 50%       4.500000e+05                    0.018850  -15750.000000
# 75%       6.795000e+05                    0.028663  -12413.000000
# max       4.050000e+06                    0.072508   -7489.000000
#
#        DAYS_EMPLOYED  DAYS_REGISTRATION  DAYS_ID_PUBLISH    OWN_CAR_AGE  \
# count  307511.000000      307511.000000    307511.000000  104582.000000
# mean    63815.045904       -4986.120328     -2994.202373      12.061091
# std    141275.766519        3522.886321      1509.450419      11.944812
# min    -17912.000000      -24672.000000     -7197.000000       0.000000
# 25%     -2760.000000       -7479.500000     -4299.000000       5.000000
# 50%     -1213.000000       -4504.000000     -3254.000000       9.000000
# 75%      -289.000000       -2010.000000     -1720.000000      15.000000
# max    365243.000000           0.000000         0.000000      91.000000
#
#        CNT_FAM_MEMBERS  REGION_RATING_CLIENT  REGION_RATING_CLIENT_W_CITY  \
# count    307509.000000         307511.000000                307511.000000
# mean          2.152665              2.052463                     2.031521
# std           0.910682              0.509034                     0.502737
# min           1.000000              1.000000                     1.000000
# 25%           2.000000              2.000000                     2.000000
# 50%           2.000000              2.000000                     2.000000
# 75%           3.000000              2.000000                     2.000000
# max          20.000000              3.000000                     3.000000
#
#        HOUR_APPR_PROCESS_START   EXT_SOURCE_1  EXT_SOURCE_2   EXT_SOURCE_3  \
# count            307511.000000  134133.000000  3.068510e+05  246546.000000
# mean                 12.063419       0.502130  5.143927e-01       0.510853
# std                   3.265832       0.211062  1.910602e-01       0.194844
# min                   0.000000       0.014568  8.173617e-08       0.000527
# 25%                  10.000000       0.334007  3.924574e-01       0.370650
# 50%                  12.000000       0.505998  5.659614e-01       0.535276
# 75%                  14.000000       0.675053  6.636171e-01       0.669057
# max                  23.000000       0.962693  8.549997e-01       0.896010
#
#        APARTMENTS_AVG  BASEMENTAREA_AVG  YEARS_BEGINEXPLUATATION_AVG  \
# count    151450.00000     127568.000000                157504.000000
# mean          0.11744          0.088442                     0.977735
# std           0.10824          0.082438                     0.059223
# min           0.00000          0.000000                     0.000000
# 25%           0.05770          0.044200                     0.976700
# 50%           0.08760          0.076300                     0.981600
# 75%           0.14850          0.112200                     0.986600
# max           1.00000          1.000000                     1.000000
#
#        YEARS_BUILD_AVG  COMMONAREA_AVG  ELEVATORS_AVG  ENTRANCES_AVG  \
# count    103023.000000    92646.000000  143620.000000  152683.000000
# mean          0.752471        0.044621       0.078942       0.149725
# std           0.113280        0.076036       0.134576       0.100049
# min           0.000000        0.000000       0.000000       0.000000
# 25%           0.687200        0.007800       0.000000       0.069000
# 50%           0.755200        0.021100       0.000000       0.137900
# 75%           0.823200        0.051500       0.120000       0.206900
# max           1.000000        1.000000       1.000000       1.000000
#
#        FLOORSMAX_AVG  FLOORSMIN_AVG   LANDAREA_AVG  LIVINGAPARTMENTS_AVG  \
# count  154491.000000   98869.000000  124921.000000          97312.000000
# mean        0.226282       0.231894       0.066333              0.100775
# std         0.144641       0.161380       0.081184              0.092576
# min         0.000000       0.000000       0.000000              0.000000
# 25%         0.166700       0.083300       0.018700              0.050400
# 50%         0.166700       0.208300       0.048100              0.075600
# 75%         0.333300       0.375000       0.085600              0.121000
# max         1.000000       1.000000       1.000000              1.000000
#
#        LIVINGAREA_AVG  NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  \
# count   153161.000000             93997.000000      137829.000000
# mean         0.107399                 0.008809           0.028358
# std          0.110565                 0.047732           0.069523
# min          0.000000                 0.000000           0.000000
# 25%          0.045300                 0.000000           0.000000
# 50%          0.074500                 0.000000           0.003600
# 75%          0.129900                 0.003900           0.027700
# max          1.000000                 1.000000           1.000000
#
#        APARTMENTS_MODE  BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  \
# count    151450.000000      127568.000000                 157504.000000
# mean          0.114231           0.087543                      0.977065
# std           0.107936           0.084307                      0.064575
# min           0.000000           0.000000                      0.000000
# 25%           0.052500           0.040700                      0.976700
# 50%           0.084000           0.074600                      0.981600
# 75%           0.143900           0.112400                      0.986600
# max           1.000000           1.000000                      1.000000
#
#        YEARS_BUILD_MODE  COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  \
# count     103023.000000     92646.000000   143620.000000   152683.000000
# mean           0.759637         0.042553        0.074490        0.145193
# std            0.110111         0.074445        0.132256        0.100977
# min            0.000000         0.000000        0.000000        0.000000
# 25%            0.699400         0.007200        0.000000        0.069000
# 50%            0.764800         0.019000        0.000000        0.137900
# 75%            0.823600         0.049000        0.120800        0.206900
# max            1.000000         1.000000        1.000000        1.000000
#
#        FLOORSMAX_MODE  FLOORSMIN_MODE  LANDAREA_MODE  LIVINGAPARTMENTS_MODE  \
# count   154491.000000    98869.000000  124921.000000           97312.000000
# mean         0.222315        0.228058       0.064958               0.105645
# std          0.143709        0.161160       0.081750               0.097880
# min          0.000000        0.000000       0.000000               0.000000
# 25%          0.166700        0.083300       0.016600               0.054200
# 50%          0.166700        0.208300       0.045800               0.077100
# 75%          0.333300        0.375000       0.084100               0.131300
# max          1.000000        1.000000       1.000000               1.000000
#
#        LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  \
# count    153161.000000              93997.000000       137829.000000
# mean          0.105975                  0.008076            0.027022
# std           0.111845                  0.046276            0.070254
# min           0.000000                  0.000000            0.000000
# 25%           0.042700                  0.000000            0.000000
# 50%           0.073100                  0.000000            0.001100
# 75%           0.125200                  0.003900            0.023100
# max           1.000000                  1.000000            1.000000
#
#        APARTMENTS_MEDI  BASEMENTAREA_MEDI  YEARS_BEGINEXPLUATATION_MEDI  \
# count    151450.000000      127568.000000                 157504.000000
# mean          0.117850           0.087955                      0.977752
# std           0.109076           0.082179                      0.059897
# min           0.000000           0.000000                      0.000000
# 25%           0.058300           0.043700                      0.976700
# 50%           0.086400           0.075800                      0.981600
# 75%           0.148900           0.111600                      0.986600
# max           1.000000           1.000000                      1.000000
#
#        YEARS_BUILD_MEDI  COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  \
# count     103023.000000     92646.000000   143620.000000   152683.000000
# mean           0.755746         0.044595        0.078078        0.149213
# std            0.112066         0.076144        0.134467        0.100368
# min            0.000000         0.000000        0.000000        0.000000
# 25%            0.691400         0.007900        0.000000        0.069000
# 50%            0.758500         0.020800        0.000000        0.137900
# 75%            0.825600         0.051300        0.120000        0.206900
# max            1.000000         1.000000        1.000000        1.000000
#
#        FLOORSMAX_MEDI  FLOORSMIN_MEDI  LANDAREA_MEDI  LIVINGAPARTMENTS_MEDI  \
# count   154491.000000    98869.000000  124921.000000           97312.000000
# mean         0.225897        0.231625       0.067169               0.101954
# std          0.145067        0.161934       0.082167               0.093642
# min          0.000000        0.000000       0.000000               0.000000
# 25%          0.166700        0.083300       0.018700               0.051300
# 50%          0.166700        0.208300       0.048700               0.076100
# 75%          0.333300        0.375000       0.086800               0.123100
# max          1.000000        1.000000       1.000000               1.000000
#
#        LIVINGAREA_MEDI  NONLIVINGAPARTMENTS_MEDI  NONLIVINGAREA_MEDI  \
# count    153161.000000              93997.000000       137829.000000
# mean          0.108607                  0.008651            0.028236
# std           0.112260                  0.047415            0.070166
# min           0.000000                  0.000000            0.000000
# 25%           0.045700                  0.000000            0.000000
# 50%           0.074900                  0.000000            0.003100
# 75%           0.130300                  0.003900            0.026600
# max           1.000000                  1.000000            1.000000
#
#        TOTALAREA_MODE  OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  \
# count   159080.000000             306490.000000             306490.000000
# mean         0.102547                  1.422245                  0.143421
# std          0.107462                  2.400989                  0.446698
# min          0.000000                  0.000000                  0.000000
# 25%          0.041200                  0.000000                  0.000000
# 50%          0.068800                  0.000000                  0.000000
# 75%          0.127600                  2.000000                  0.000000
# max          1.000000                348.000000                 34.000000
#
#        OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE  \
# count             306490.000000             306490.000000
# mean                   1.405292                  0.100049
# std                    2.379803                  0.362291
# min                    0.000000                  0.000000
# 25%                    0.000000                  0.000000
# 50%                    0.000000                  0.000000
# 75%                    2.000000                  0.000000
# max                  344.000000                 24.000000
#
#        DAYS_LAST_PHONE_CHANGE  AMT_REQ_CREDIT_BUREAU_HOUR  \
# count           307510.000000               265992.000000
# mean              -962.858788                    0.006402
# std                826.808487                    0.083849
# min              -4292.000000                    0.000000
# 25%              -1570.000000                    0.000000
# 50%               -757.000000                    0.000000
# 75%               -274.000000                    0.000000
# max                  0.000000                    4.000000
#
#        AMT_REQ_CREDIT_BUREAU_DAY  AMT_REQ_CREDIT_BUREAU_WEEK  \
# count              265992.000000               265992.000000
# mean                    0.007000                    0.034362
# std                     0.110757                    0.204685
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    0.000000
# 75%                     0.000000                    0.000000
# max                     9.000000                    8.000000
#
#        AMT_REQ_CREDIT_BUREAU_MON  AMT_REQ_CREDIT_BUREAU_QRT  \
# count              265992.000000              265992.000000
# mean                    0.267395                   0.265474
# std                     0.916002                   0.794056
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# 50%                     0.000000                   0.000000
# 75%                     0.000000                   0.000000
# max                    27.000000                 261.000000
#
#        AMT_REQ_CREDIT_BUREAU_YEAR
# count               265992.000000
# mean                     1.899974
# std                      1.869295
# min                      0.000000
# 25%                      0.000000
# 50%                      1.000000
# 75%                      3.000000
# max                     25.000000

# %%
def outliers (dataf_numeric):
    for i in range (0, len(dataf_numeric.columns)):
        print(i, ' ',dataf_numeric.columns[i])
        q1,q3 =np.percentile(dataf_numeric[dataf_numeric.columns[i]], [25, 75])
        iqr = q3 - q1
        lim_haute = min(max(dataf_numeric[dataf_numeric.columns[i]]),q3+1.5*iqr)
        lim_basse = max(min(dataf_numeric[dataf_numeric.columns[i]]),q1-1.5*iqr)
        display(dataf_numeric[[dataf_numeric.columns[i]]].loc[dataf_numeric[dataf_numeric.columns[i]]> lim_haute]),dataf_numeric[[dataf_numeric.columns[i]]].loc[dataf_numeric[dataf_numeric.columns[i]]< lim_basse]
        print('\n','---------------------------------------------------------------------------------------------')

# %%
outliers(data.select_dtypes(['int64','float64']))
# Out:
# 0   CNT_CHILDREN
#             CNT_CHILDREN
# SK_ID_CURR
# 100108                 3
# 100110                 3
# 100166                 3
# 100209                 3
# 100211                 3
# ...                  ...
# 456016                 4
# 456053                 3
# 456113                 3
# 456201                 3
# 456245                 3
#
# [4272 rows x 1 columns]
#  ---------------------------------------------------------------------------------------------
# 1   AMT_INCOME_TOTAL
#             AMT_INCOME_TOTAL
# SK_ID_CURR
# 100010              360000.0
# 100026              450000.0
# 100039              360000.0
# 100056              360000.0
# 100059              540000.0
# ...                      ...
# 456199              382500.0
# 456217              360000.0
# 456228              540000.0
# 456236              585000.0
# 456240              360000.0
#
# [14035 rows x 1 columns]
#  ---------------------------------------------------------------------------------------------
# 2   AMT_CREDIT
#             AMT_CREDIT
# SK_ID_CURR
# 100071       1663987.5
# 100157       1755000.0
# 100219       2250000.0
# 100273       1710000.0
# 100361       1800000.0
# ...                ...
# 455924       1827549.0
# 455969       1724220.0
# 456134       1718473.5
# 456155       1971072.0
# 456216       1762110.0
#
# [6562 rows x 1 columns]
#  ---------------------------------------------------------------------------------------------
# 3   AMT_ANNUITY
# Empty DataFrame
# Columns: [AMT_ANNUITY]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 4   AMT_GOODS_PRICE
# Empty DataFrame
# Columns: [AMT_GOODS_PRICE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 5   REGION_POPULATION_RELATIVE
#             REGION_POPULATION_RELATIVE
# SK_ID_CURR
# 100077                        0.072508
# 100101                        0.072508
# 100124                        0.072508
# 100131                        0.072508
# 100218                        0.072508
# ...                                ...
# 455924                        0.072508
# 456125                        0.072508
# 456178                        0.072508
# 456230                        0.072508
# 456242                        0.072508
#
# [8412 rows x 1 columns]
#  ---------------------------------------------------------------------------------------------
# 6   DAYS_BIRTH
# Empty DataFrame
# Columns: [DAYS_BIRTH]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 7   DAYS_EMPLOYED
#             DAYS_EMPLOYED
# SK_ID_CURR
# 100011             365243
# 100015             365243
# 100027             365243
# 100045             365243
# 100050             365243
# ...                   ...
# 456209             365243
# 456227             365243
# 456231             365243
# 456249             365243
# 456252             365243
#
# [55374 rows x 1 columns]
#  ---------------------------------------------------------------------------------------------
# 8   DAYS_REGISTRATION
# Empty DataFrame
# Columns: [DAYS_REGISTRATION]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 9   DAYS_ID_PUBLISH
# Empty DataFrame
# Columns: [DAYS_ID_PUBLISH]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 10   OWN_CAR_AGE
# Empty DataFrame
# Columns: [OWN_CAR_AGE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 11   CNT_FAM_MEMBERS
# Empty DataFrame
# Columns: [CNT_FAM_MEMBERS]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 12   REGION_RATING_CLIENT
#             REGION_RATING_CLIENT
# SK_ID_CURR
# 100010                         3
# 100019                         3
# 100026                         3
# 100027                         3
# 100031                         3
# ...                          ...
# 456204                         3
# 456208                         3
# 456213                         3
# 456214                         3
# 456253                         3
#
# [48330 rows x 1 columns]
#  ---------------------------------------------------------------------------------------------
# 13   REGION_RATING_CLIENT_W_CITY
#             REGION_RATING_CLIENT_W_CITY
# SK_ID_CURR
# 100010                                3
# 100019                                3
# 100027                                3
# 100049                                3
# 100055                                3
# ...                                 ...
# 456204                                3
# 456208                                3
# 456213                                3
# 456214                                3
# 456253                                3
#
# [43860 rows x 1 columns]
#  ---------------------------------------------------------------------------------------------
# 14   HOUR_APPR_PROCESS_START
#             HOUR_APPR_PROCESS_START
# SK_ID_CURR
# 100126                           21
# 100645                           22
# 101907                           22
# 102192                           21
# 102889                           22
# ...                             ...
# 455124                           21
# 455241                           21
# 455311                           21
# 455427                           21
# 456064                           21
#
# [596 rows x 1 columns]
#  ---------------------------------------------------------------------------------------------
# 15   EXT_SOURCE_1
# Empty DataFrame
# Columns: [EXT_SOURCE_1]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 16   EXT_SOURCE_2
# Empty DataFrame
# Columns: [EXT_SOURCE_2]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 17   EXT_SOURCE_3
# Empty DataFrame
# Columns: [EXT_SOURCE_3]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 18   APARTMENTS_AVG
# Empty DataFrame
# Columns: [APARTMENTS_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 19   BASEMENTAREA_AVG
# Empty DataFrame
# Columns: [BASEMENTAREA_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 20   YEARS_BEGINEXPLUATATION_AVG
# Empty DataFrame
# Columns: [YEARS_BEGINEXPLUATATION_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 21   YEARS_BUILD_AVG
# Empty DataFrame
# Columns: [YEARS_BUILD_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 22   COMMONAREA_AVG
# Empty DataFrame
# Columns: [COMMONAREA_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 23   ELEVATORS_AVG
# Empty DataFrame
# Columns: [ELEVATORS_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 24   ENTRANCES_AVG
# Empty DataFrame
# Columns: [ENTRANCES_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 25   FLOORSMAX_AVG
# Empty DataFrame
# Columns: [FLOORSMAX_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 26   FLOORSMIN_AVG
# Empty DataFrame
# Columns: [FLOORSMIN_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 27   LANDAREA_AVG
# Empty DataFrame
# Columns: [LANDAREA_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 28   LIVINGAPARTMENTS_AVG
# Empty DataFrame
# Columns: [LIVINGAPARTMENTS_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 29   LIVINGAREA_AVG
# Empty DataFrame
# Columns: [LIVINGAREA_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 30   NONLIVINGAPARTMENTS_AVG
# Empty DataFrame
# Columns: [NONLIVINGAPARTMENTS_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 31   NONLIVINGAREA_AVG
# Empty DataFrame
# Columns: [NONLIVINGAREA_AVG]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 32   APARTMENTS_MODE
# Empty DataFrame
# Columns: [APARTMENTS_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 33   BASEMENTAREA_MODE
# Empty DataFrame
# Columns: [BASEMENTAREA_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 34   YEARS_BEGINEXPLUATATION_MODE
# Empty DataFrame
# Columns: [YEARS_BEGINEXPLUATATION_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 35   YEARS_BUILD_MODE
# Empty DataFrame
# Columns: [YEARS_BUILD_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 36   COMMONAREA_MODE
# Empty DataFrame
# Columns: [COMMONAREA_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 37   ELEVATORS_MODE
# Empty DataFrame
# Columns: [ELEVATORS_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 38   ENTRANCES_MODE
# Empty DataFrame
# Columns: [ENTRANCES_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 39   FLOORSMAX_MODE
# Empty DataFrame
# Columns: [FLOORSMAX_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 40   FLOORSMIN_MODE
# Empty DataFrame
# Columns: [FLOORSMIN_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 41   LANDAREA_MODE
# Empty DataFrame
# Columns: [LANDAREA_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 42   LIVINGAPARTMENTS_MODE
# Empty DataFrame
# Columns: [LIVINGAPARTMENTS_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 43   LIVINGAREA_MODE
# Empty DataFrame
# Columns: [LIVINGAREA_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 44   NONLIVINGAPARTMENTS_MODE
# Empty DataFrame
# Columns: [NONLIVINGAPARTMENTS_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 45   NONLIVINGAREA_MODE
# Empty DataFrame
# Columns: [NONLIVINGAREA_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 46   APARTMENTS_MEDI
# Empty DataFrame
# Columns: [APARTMENTS_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 47   BASEMENTAREA_MEDI
# Empty DataFrame
# Columns: [BASEMENTAREA_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 48   YEARS_BEGINEXPLUATATION_MEDI
# Empty DataFrame
# Columns: [YEARS_BEGINEXPLUATATION_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 49   YEARS_BUILD_MEDI
# Empty DataFrame
# Columns: [YEARS_BUILD_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 50   COMMONAREA_MEDI
# Empty DataFrame
# Columns: [COMMONAREA_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 51   ELEVATORS_MEDI
# Empty DataFrame
# Columns: [ELEVATORS_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 52   ENTRANCES_MEDI
# Empty DataFrame
# Columns: [ENTRANCES_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 53   FLOORSMAX_MEDI
# Empty DataFrame
# Columns: [FLOORSMAX_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 54   FLOORSMIN_MEDI
# Empty DataFrame
# Columns: [FLOORSMIN_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 55   LANDAREA_MEDI
# Empty DataFrame
# Columns: [LANDAREA_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 56   LIVINGAPARTMENTS_MEDI
# Empty DataFrame
# Columns: [LIVINGAPARTMENTS_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 57   LIVINGAREA_MEDI
# Empty DataFrame
# Columns: [LIVINGAREA_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 58   NONLIVINGAPARTMENTS_MEDI
# Empty DataFrame
# Columns: [NONLIVINGAPARTMENTS_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 59   NONLIVINGAREA_MEDI
# Empty DataFrame
# Columns: [NONLIVINGAREA_MEDI]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 60   TOTALAREA_MODE
# Empty DataFrame
# Columns: [TOTALAREA_MODE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 61   OBS_30_CNT_SOCIAL_CIRCLE
# Empty DataFrame
# Columns: [OBS_30_CNT_SOCIAL_CIRCLE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 62   DEF_30_CNT_SOCIAL_CIRCLE
# Empty DataFrame
# Columns: [DEF_30_CNT_SOCIAL_CIRCLE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 63   OBS_60_CNT_SOCIAL_CIRCLE
# Empty DataFrame
# Columns: [OBS_60_CNT_SOCIAL_CIRCLE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 64   DEF_60_CNT_SOCIAL_CIRCLE
# Empty DataFrame
# Columns: [DEF_60_CNT_SOCIAL_CIRCLE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 65   DAYS_LAST_PHONE_CHANGE
# Empty DataFrame
# Columns: [DAYS_LAST_PHONE_CHANGE]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 66   AMT_REQ_CREDIT_BUREAU_HOUR
# Empty DataFrame
# Columns: [AMT_REQ_CREDIT_BUREAU_HOUR]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 67   AMT_REQ_CREDIT_BUREAU_DAY
# Empty DataFrame
# Columns: [AMT_REQ_CREDIT_BUREAU_DAY]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 68   AMT_REQ_CREDIT_BUREAU_WEEK
# Empty DataFrame
# Columns: [AMT_REQ_CREDIT_BUREAU_WEEK]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 69   AMT_REQ_CREDIT_BUREAU_MON
# Empty DataFrame
# Columns: [AMT_REQ_CREDIT_BUREAU_MON]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 70   AMT_REQ_CREDIT_BUREAU_QRT
# Empty DataFrame
# Columns: [AMT_REQ_CREDIT_BUREAU_QRT]
# Index: []
#  ---------------------------------------------------------------------------------------------
# 71   AMT_REQ_CREDIT_BUREAU_YEAR
# Empty DataFrame
# Columns: [AMT_REQ_CREDIT_BUREAU_YEAR]
# Index: []
#  ---------------------------------------------------------------------------------------------

# %%
data['AVG_NOTE']= np.mean(data.loc[:,['EXT_SOURCE_1','EXT_SOURCE_2','EXT_SOURCE_3']],axis=1)
data['AVG_NOTE']
# Out:
# SK_ID_CURR
# 100002    0.161787
# 100003    0.466757
# 100004    0.642739
# 100006    0.650442
# 100007    0.322738
#             ...
# 456251    0.413601
# 456252    0.115992
# 456253    0.499536
# 456254    0.587593
# 456255    0.518984
# Name: AVG_NOTE, Length: 307511, dtype: float64

# %%
filling_rate(data[['AVG_NOTE']])
# Out:
#              no                                 variable name    data not NaN             type    Filling Rate  %
#               0                                      AVG_NOTE          307339          float64         99.9441 %

# %%
data = pd.concat([data.loc[data.TARGET == True],data.loc[data.TARGET == False].head(170000)],axis=0)
print(data.shape)
data.head()
# Out:
# (194825, 122)
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002        True         Cash loans           M            N
# 100031        True         Cash loans           F            N
# 100047        True         Cash loans           M            N
# 100049        True         Cash loans           F            N
# 100096        True         Cash loans           F            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202500.0    406597.5
# 100031                   Y             0          112500.0    979992.0
# 100047                   Y             0          202500.0   1193580.0
# 100049                   N             0          135000.0    288873.0
# 100096                   Y             0           81000.0    252000.0
#
#             AMT_ANNUITY  AMT_GOODS_PRICE NAME_TYPE_SUITE  \
# SK_ID_CURR
# 100002          24700.5         351000.0   Unaccompanied
# 100031          27076.5         702000.0   Unaccompanied
# 100047          35028.0         855000.0   Unaccompanied
# 100049          16258.5         238500.0   Unaccompanied
# 100096          14593.5         252000.0   Unaccompanied
#
#                 NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# SK_ID_CURR
# 100002                   Working  Secondary / secondary special
# 100031                   Working  Secondary / secondary special
# 100047      Commercial associate  Secondary / secondary special
# 100049                   Working  Secondary / secondary special
# 100096                 Pensioner  Secondary / secondary special
#
#               NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  \
# SK_ID_CURR
# 100002      Single / not married  House / apartment
# 100031                     Widow  House / apartment
# 100047                   Married  House / apartment
# 100049            Civil marriage  House / apartment
# 100096                   Married  House / apartment
#
#             REGION_POPULATION_RELATIVE  DAYS_BIRTH  DAYS_EMPLOYED  \
# SK_ID_CURR
# 100002                        0.018801       -9461           -637
# 100031                        0.018029      -18724          -2628
# 100047                        0.025164      -17482          -1262
# 100049                        0.007305      -13384          -3597
# 100096                        0.028663      -24794         365243
#
#             DAYS_REGISTRATION  DAYS_ID_PUBLISH  OWN_CAR_AGE  FLAG_MOBIL  \
# SK_ID_CURR
# 100002                -3648.0            -2120          NaN        True
# 100031                -6573.0            -1827          NaN        True
# 100047                -1182.0            -1029          NaN        True
# 100049                  -45.0            -4409          NaN        True
# 100096                -5391.0            -4199          NaN        True
#
#             FLAG_EMP_PHONE  FLAG_WORK_PHONE  FLAG_CONT_MOBILE  FLAG_PHONE  \
# SK_ID_CURR
# 100002                True            False              True        True
# 100031                True            False              True       False
# 100047                True            False              True       False
# 100049                True             True              True        True
# 100096               False            False              True       False
#
#             FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  REGION_RATING_CLIENT  \
# SK_ID_CURR
# 100002           False        Laborers              1.0                     2
# 100031           False   Cooking staff              1.0                     3
# 100047           False        Laborers              2.0                     2
# 100049           False     Sales staff              2.0                     3
# 100096           False             NaN              2.0                     2
#
#             REGION_RATING_CLIENT_W_CITY WEEKDAY_APPR_PROCESS_START  \
# SK_ID_CURR
# 100002                                2                  WEDNESDAY
# 100031                                2                     MONDAY
# 100047                                2                    TUESDAY
# 100049                                3                   THURSDAY
# 100096                                2                   THURSDAY
#
#             HOUR_APPR_PROCESS_START  REG_REGION_NOT_LIVE_REGION  \
# SK_ID_CURR
# 100002                           10                       False
# 100031                            9                       False
# 100047                            9                       False
# 100049                           11                       False
# 100096                           10                       False
#
#             REG_REGION_NOT_WORK_REGION  LIVE_REGION_NOT_WORK_REGION  \
# SK_ID_CURR
# 100002                           False                        False
# 100031                           False                        False
# 100047                           False                        False
# 100049                           False                        False
# 100096                           False                        False
#
#             REG_CITY_NOT_LIVE_CITY  REG_CITY_NOT_WORK_CITY  \
# SK_ID_CURR
# 100002                       False                   False
# 100031                       False                   False
# 100047                       False                   False
# 100049                       False                   False
# 100096                       False                   False
#
#             LIVE_CITY_NOT_WORK_CITY       ORGANIZATION_TYPE  EXT_SOURCE_1  \
# SK_ID_CURR
# 100002                        False  Business Entity Type 3      0.083037
# 100031                        False  Business Entity Type 3           NaN
# 100047                        False  Business Entity Type 3           NaN
# 100049                        False           Self-employed      0.468208
# 100096                        False                     XNA           NaN
#
#             EXT_SOURCE_2  EXT_SOURCE_3  APARTMENTS_AVG  BASEMENTAREA_AVG  \
# SK_ID_CURR
# 100002          0.262949      0.139376          0.0247            0.0369
# 100031          0.548477      0.190706          0.0165            0.0089
# 100047          0.306841      0.320163          0.1309            0.1250
# 100049          0.674203      0.399676             NaN               NaN
# 100096          0.023952      0.720944             NaN               NaN
#
#             YEARS_BEGINEXPLUATATION_AVG  YEARS_BUILD_AVG  COMMONAREA_AVG  \
# SK_ID_CURR
# 100002                           0.9722           0.6192          0.0143
# 100031                           0.9732              NaN             NaN
# 100047                           0.9960           0.9456          0.0822
# 100049                              NaN              NaN             NaN
# 100096                              NaN              NaN             NaN
#
#             ELEVATORS_AVG  ENTRANCES_AVG  FLOORSMAX_AVG  FLOORSMIN_AVG  \
# SK_ID_CURR
# 100002               0.00         0.0690         0.0833         0.1250
# 100031               0.00         0.0690         0.0417            NaN
# 100047               0.16         0.1379         0.2500         0.2917
# 100049                NaN            NaN            NaN            NaN
# 100096                NaN            NaN            NaN            NaN
#
#             LANDAREA_AVG  LIVINGAPARTMENTS_AVG  LIVINGAREA_AVG  \
# SK_ID_CURR
# 100002            0.0369                0.0202          0.0190
# 100031            0.0265                   NaN          0.0094
# 100047            0.0142                0.1059          0.1267
# 100049               NaN                   NaN             NaN
# 100096               NaN                   NaN             NaN
#
#             NONLIVINGAPARTMENTS_AVG  NONLIVINGAREA_AVG  APARTMENTS_MODE  \
# SK_ID_CURR
# 100002                       0.0000             0.0000           0.0252
# 100031                          NaN             0.0000           0.0168
# 100047                       0.0039             0.0078           0.1334
# 100049                          NaN                NaN              NaN
# 100096                          NaN                NaN              NaN
#
#             BASEMENTAREA_MODE  YEARS_BEGINEXPLUATATION_MODE  YEARS_BUILD_MODE  \
# SK_ID_CURR
# 100002                 0.0383                        0.9722            0.6341
# 100031                 0.0092                        0.9732               NaN
# 100047                 0.1297                        0.9960            0.9477
# 100049                    NaN                           NaN               NaN
# 100096                    NaN                           NaN               NaN
#
#             COMMONAREA_MODE  ELEVATORS_MODE  ENTRANCES_MODE  FLOORSMAX_MODE  \
# SK_ID_CURR
# 100002               0.0144          0.0000          0.0690          0.0833
# 100031                  NaN          0.0000          0.0690          0.0417
# 100047               0.0830          0.1611          0.1379          0.2500
# 100049                  NaN             NaN             NaN             NaN
# 100096                  NaN             NaN             NaN             NaN
#
#             FLOORSMIN_MODE  LANDAREA_MODE  LIVINGAPARTMENTS_MODE  \
# SK_ID_CURR
# 100002              0.1250         0.0377                 0.0220
# 100031                 NaN         0.0271                    NaN
# 100047              0.2917         0.0145                 0.1157
# 100049                 NaN            NaN                    NaN
# 100096                 NaN            NaN                    NaN
#
#             LIVINGAREA_MODE  NONLIVINGAPARTMENTS_MODE  NONLIVINGAREA_MODE  \
# SK_ID_CURR
# 100002               0.0198                    0.0000              0.0000
# 100031               0.0083                       NaN              0.0000
# 100047               0.1320                    0.0039              0.0082
# 100049                  NaN                       NaN                 NaN
# 100096                  NaN                       NaN                 NaN
#
#             APARTMENTS_MEDI  BASEMENTAREA_MEDI  YEARS_BEGINEXPLUATATION_MEDI  \
# SK_ID_CURR
# 100002               0.0250             0.0369                        0.9722
# 100031               0.0167             0.0089                        0.9732
# 100047               0.1322             0.1250                        0.9960
# 100049                  NaN                NaN                           NaN
# 100096                  NaN                NaN                           NaN
#
#             YEARS_BUILD_MEDI  COMMONAREA_MEDI  ELEVATORS_MEDI  ENTRANCES_MEDI  \
# SK_ID_CURR
# 100002                0.6243           0.0144            0.00          0.0690
# 100031                   NaN              NaN            0.00          0.0690
# 100047                0.9463           0.0827            0.16          0.1379
# 100049                   NaN              NaN             NaN             NaN
# 100096                   NaN              NaN             NaN             NaN
#
#             FLOORSMAX_MEDI  FLOORSMIN_MEDI  LANDAREA_MEDI  \
# SK_ID_CURR
# 100002              0.0833          0.1250         0.0375
# 100031              0.0417             NaN         0.0270
# 100047              0.2500          0.2917         0.0144
# 100049                 NaN             NaN            NaN
# 100096                 NaN             NaN            NaN
#
#             LIVINGAPARTMENTS_MEDI  LIVINGAREA_MEDI  NONLIVINGAPARTMENTS_MEDI  \
# SK_ID_CURR
# 100002                     0.0205           0.0193                    0.0000
# 100031                        NaN           0.0096                       NaN
# 100047                     0.1077           0.1290                    0.0039
# 100049                        NaN              NaN                       NaN
# 100096                        NaN              NaN                       NaN
#
#             NONLIVINGAREA_MEDI FONDKAPREMONT_MODE  HOUSETYPE_MODE  \
# SK_ID_CURR
# 100002                  0.0000   reg oper account  block of flats
# 100031                  0.0000                NaN  block of flats
# 100047                  0.0079   org spec account  block of flats
# 100049                     NaN                NaN             NaN
# 100096                     NaN                NaN             NaN
#
#             TOTALAREA_MODE WALLSMATERIAL_MODE EMERGENCYSTATE_MODE  \
# SK_ID_CURR
# 100002              0.0149       Stone, brick                  No
# 100031              0.0085             Wooden                 Yes
# 100047              0.1463       Stone, brick                  No
# 100049                 NaN                NaN                 NaN
# 100096                 NaN                NaN                 NaN
#
#             OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100031                          10.0                       1.0
# 100047                           0.0                       0.0
# 100049                           1.0                       0.0
# 100096                           1.0                       1.0
#
#             OBS_60_CNT_SOCIAL_CIRCLE  DEF_60_CNT_SOCIAL_CIRCLE  \
# SK_ID_CURR
# 100002                           2.0                       2.0
# 100031                          10.0                       0.0
# 100047                           0.0                       0.0
# 100049                           1.0                       0.0
# 100096                           1.0                       1.0
#
#             DAYS_LAST_PHONE_CHANGE  FLAG_DOCUMENT_2  FLAG_DOCUMENT_3  \
# SK_ID_CURR
# 100002                     -1134.0            False             True
# 100031                      -161.0            False             True
# 100047                     -1075.0            False             True
# 100049                     -1480.0            False             True
# 100096                         0.0            False            False
#
#             FLAG_DOCUMENT_4  FLAG_DOCUMENT_5  FLAG_DOCUMENT_6  \
# SK_ID_CURR
# 100002                False            False            False
# 100031                False            False            False
# 100047                False            False            False
# 100049                False            False            False
# 100096                False            False             True
#
#             FLAG_DOCUMENT_7  FLAG_DOCUMENT_8  FLAG_DOCUMENT_9  \
# SK_ID_CURR
# 100002                False            False            False
# 100031                False            False            False
# 100047                False            False            False
# 100049                False            False            False
# 100096                False            False            False
#
#             FLAG_DOCUMENT_10  FLAG_DOCUMENT_11  FLAG_DOCUMENT_12  \
# SK_ID_CURR
# 100002                 False             False             False
# 100031                 False             False             False
# 100047                 False             False             False
# 100049                 False             False             False
# 100096                 False             False             False
#
#             FLAG_DOCUMENT_13  FLAG_DOCUMENT_14  FLAG_DOCUMENT_15  \
# SK_ID_CURR
# 100002                 False             False             False
# 100031                 False             False             False
# 100047                 False             False             False
# 100049                 False             False             False
# 100096                 False             False             False
#
#             FLAG_DOCUMENT_16  FLAG_DOCUMENT_17  FLAG_DOCUMENT_18  \
# SK_ID_CURR
# 100002                 False             False             False
# 100031                  True             False             False
# 100047                 False             False             False
# 100049                 False             False             False
# 100096                 False             False             False
#
#             FLAG_DOCUMENT_19  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21  \
# SK_ID_CURR
# 100002                 False             False             False
# 100031                 False             False             False
# 100047                 False             False             False
# 100049                 False             False             False
# 100096                 False             False             False
#
#             AMT_REQ_CREDIT_BUREAU_HOUR  AMT_REQ_CREDIT_BUREAU_DAY  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100031                             0.0                        0.0
# 100047                             0.0                        0.0
# 100049                             0.0                        0.0
# 100096                             0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# SK_ID_CURR
# 100002                             0.0                        0.0
# 100031                             0.0                        0.0
# 100047                             0.0                        2.0
# 100049                             0.0                        0.0
# 100096                             0.0                        0.0
#
#             AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR  AVG_NOTE
# SK_ID_CURR
# 100002                            0.0                         1.0  0.161787
# 100031                            2.0                         2.0  0.369592
# 100047                            0.0                         4.0  0.313502
# 100049                            0.0                         2.0  0.514029
# 100096                            0.0                         0.0  0.372448

# %%
data[['TARGET']].value_counts()
# Out:
# TARGET
# False     170000
# True       24825
# dtype: int64

# %%
X = data.drop(columns=['TARGET'],axis=1)
y = data.TARGET

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    train_size=0.8,
                                                    random_state=42)

# %%
print("X_train",X_train.shape)
print("y_train",y_train.shape)
print("X_test",X_test.shape)
print("y_test",y_test.shape)
# Out:
# X_train (246008, 121)
# y_train (246008,)
# X_test (61503, 121)
# y_test (61503,)

# %%
cat_features = X.select_dtypes(include=["object","bool"]).columns
liste_catego = X.columns.get_indexer(cat_features)

# %%
liste_catego
# Out:
# array([  0,   1,   2,   3,   9,  10,  11,  12,  13,  20,  21,  22,  23,
#         24,  25,  26,  30,  32,  33,  34,  35,  36,  37,  38,  84,  85,
#         87,  88,  94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104,
#        105, 106, 107, 108, 109, 110, 111, 112, 113], dtype=int64)

# %%
# définition des pipelines

numeric_imputer = SimpleImputer(strategy="median")
numeric_scaler = RobustScaler()

categorical_imputer = SimpleImputer(strategy="constant", fill_value="missing")
categorical_transformer = OneHotEncoder(handle_unknown="ignore", drop=None)

# imputer
imputer = ColumnTransformer(
            transformers=[
                
                (
                    "category_1",
                    make_pipeline(categorical_imputer),
                    make_column_selector(dtype_include=["object", "bool"]),
                ),
                (
                    "number_1",
                    make_pipeline(numeric_imputer),
                    make_column_selector(dtype_include=['number']),
                ),
            ]
        )

nb_feat_tot = X_train.shape[1]
categorical_index = list(range(0,len(cat_features)))
numerical_index = list(range(len(cat_features),nb_feat_tot))

# scaler and transformer
scaler_transf = ColumnTransformer(
            transformers=[
                (
                    "category_2",
                    categorical_transformer,
                    make_column_selector(dtype_include='number'),
                ),
                
                (
                    "number_2",
                    numeric_scaler,
                    make_column_selector(dtype_include=["object", "bool"]),
                ),
                
            ]
        )


preprocessor = ColumnTransformer(
            transformers=[
                
                (
                    "category",
                    make_pipeline(categorical_imputer,categorical_transformer),
                    make_column_selector(dtype_include=["object", "bool"]),
                ),
                (
                    "number",
                    make_pipeline(numeric_imputer,numeric_scaler),
                    make_column_selector(dtype_include='number'),
                ),
            ]
        )

# %%
ftwo_scorer = make_scorer(fbeta_score, beta=2,greater_is_better=True,)

# %%
    resample = imbpipeline(
        steps=[
        ('imputer', imputer),
        ('smote',SMOTENC(categorical_features=range(0,len(cat_features)),sampling_strategy='minority', random_state=42))])
    resample
# Out:
# Pipeline(memory=None,
#          steps=[('imputer',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('category_1',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value='missing',
#                                                                                  missing_values=nan,
#                                                                                  strategy='constant',
#                                                                                  verbose=0))],
#                                                            verbose=False),
#                                                   <sklearn.comp...
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='median',
#                                                                                  verbose=0))],
#                                                            verbose=False),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x000002512BC598C8>)],
#                                    verbose=False)),
#                 ('smote',
#                  SMOTENC(categorical_features=range(0, 48), k_neighbors=5,
#                          n_jobs=None, random_state=42,
#                          sampling_strategy='minority'))],
#          verbose=False)

# %%
X_resample, y_resample = resample.fit_resample(X_train,y_train)

# %%
X_resample.shape
# Out:
# (452264, 121)

# %%
feat_names=[]
for steps in resample.get_params()['imputer'].transformers_ : 
    feat_names.extend(steps[2])
    
feat_names
# Out:
# ['NAME_CONTRACT_TYPE',
#  'CODE_GENDER',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'NAME_TYPE_SUITE',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_HOUSING_TYPE',
#  'FLAG_MOBIL',
#  'FLAG_EMP_PHONE',
#  'FLAG_WORK_PHONE',
#  'FLAG_CONT_MOBILE',
#  'FLAG_PHONE',
#  'FLAG_EMAIL',
#  'OCCUPATION_TYPE',
#  'WEEKDAY_APPR_PROCESS_START',
#  'REG_REGION_NOT_LIVE_REGION',
#  'REG_REGION_NOT_WORK_REGION',
#  'LIVE_REGION_NOT_WORK_REGION',
#  'REG_CITY_NOT_LIVE_CITY',
#  'REG_CITY_NOT_WORK_CITY',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'ORGANIZATION_TYPE',
#  'FONDKAPREMONT_MODE',
#  'HOUSETYPE_MODE',
#  'WALLSMATERIAL_MODE',
#  'EMERGENCYSTATE_MODE',
#  'FLAG_DOCUMENT_2',
#  'FLAG_DOCUMENT_3',
#  'FLAG_DOCUMENT_4',
#  'FLAG_DOCUMENT_5',
#  'FLAG_DOCUMENT_6',
#  'FLAG_DOCUMENT_7',
#  'FLAG_DOCUMENT_8',
#  'FLAG_DOCUMENT_9',
#  'FLAG_DOCUMENT_10',
#  'FLAG_DOCUMENT_11',
#  'FLAG_DOCUMENT_12',
#  'FLAG_DOCUMENT_13',
#  'FLAG_DOCUMENT_14',
#  'FLAG_DOCUMENT_15',
#  'FLAG_DOCUMENT_16',
#  'FLAG_DOCUMENT_17',
#  'FLAG_DOCUMENT_18',
#  'FLAG_DOCUMENT_19',
#  'FLAG_DOCUMENT_20',
#  'FLAG_DOCUMENT_21',
#  'CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'REGION_POPULATION_RELATIVE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_REGISTRATION',
#  'DAYS_ID_PUBLISH',
#  'OWN_CAR_AGE',
#  'CNT_FAM_MEMBERS',
#  'REGION_RATING_CLIENT',
#  'REGION_RATING_CLIENT_W_CITY',
#  'HOUR_APPR_PROCESS_START',
#  'EXT_SOURCE_1',
#  'EXT_SOURCE_2',
#  'EXT_SOURCE_3',
#  'APARTMENTS_AVG',
#  'BASEMENTAREA_AVG',
#  'YEARS_BEGINEXPLUATATION_AVG',
#  'YEARS_BUILD_AVG',
#  'COMMONAREA_AVG',
#  'ELEVATORS_AVG',
#  'ENTRANCES_AVG',
#  'FLOORSMAX_AVG',
#  'FLOORSMIN_AVG',
#  'LANDAREA_AVG',
#  'LIVINGAPARTMENTS_AVG',
#  'LIVINGAREA_AVG',
#  'NONLIVINGAPARTMENTS_AVG',
#  'NONLIVINGAREA_AVG',
#  'APARTMENTS_MODE',
#  'BASEMENTAREA_MODE',
#  'YEARS_BEGINEXPLUATATION_MODE',
#  'YEARS_BUILD_MODE',
#  'COMMONAREA_MODE',
#  'ELEVATORS_MODE',
#  'ENTRANCES_MODE',
#  'FLOORSMAX_MODE',
#  'FLOORSMIN_MODE',
#  'LANDAREA_MODE',
#  'LIVINGAPARTMENTS_MODE',
#  'LIVINGAREA_MODE',
#  'NONLIVINGAPARTMENTS_MODE',
#  'NONLIVINGAREA_MODE',
#  'APARTMENTS_MEDI',
#  'BASEMENTAREA_MEDI',
#  'YEARS_BEGINEXPLUATATION_MEDI',
#  'YEARS_BUILD_MEDI',
#  'COMMONAREA_MEDI',
#  'ELEVATORS_MEDI',
#  'ENTRANCES_MEDI',
#  'FLOORSMAX_MEDI',
#  'FLOORSMIN_MEDI',
#  'LANDAREA_MEDI',
#  'LIVINGAPARTMENTS_MEDI',
#  'LIVINGAREA_MEDI',
#  'NONLIVINGAPARTMENTS_MEDI',
#  'NONLIVINGAREA_MEDI',
#  'TOTALAREA_MODE',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'OBS_60_CNT_SOCIAL_CIRCLE',
#  'DEF_60_CNT_SOCIAL_CIRCLE',
#  'DAYS_LAST_PHONE_CHANGE',
#  'AMT_REQ_CREDIT_BUREAU_HOUR',
#  'AMT_REQ_CREDIT_BUREAU_DAY',
#  'AMT_REQ_CREDIT_BUREAU_WEEK',
#  'AMT_REQ_CREDIT_BUREAU_MON',
#  'AMT_REQ_CREDIT_BUREAU_QRT',
#  'AMT_REQ_CREDIT_BUREAU_YEAR',
#  'AVG_NOTE']

# %%
w={True:280000, False:25000}

classifier = Pipeline(
    steps= [
    ('preprocessor',preprocessor),
    ('k_best',SelectKBest(f_classif, k=35)),
    #('select_fpr',SelectFpr()),
    ('logistic',LogisticRegression(max_iter=350,class_weight=w, random_state=42)), #0.5 
    #('model_xgb', XGBClassifier(n_estimators = 250,learning_rate = 0.9,objective='binary:logistic',use_label_encoder=False,eval_metric=ftwo_scorer)) #0.5
    #('model_ada',AdaBoostClassifier(n_estimators=250, learning_rate=0.9)),
    #('model_random_f',RandomForestClassifier(n_estimators=200, criterion='entropy')),   #beaucoup trop long...
    #('extra_tree',ExtraTreesClassifier(n_estimators=200,))
    #('svc',LinearSVC())
    #('lda',LinearDiscriminantAnalysis())
    #('ridge',RidgeClassifier())
])
classifier
# Out:
# Pipeline(memory=None,
#          steps=[('preprocessor',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('category',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value='missing',
#                                                                                  missing_values=nan,
#                                                                                  strategy='constant',
#                                                                                  verbose=0)),
#                                                                   ('onehotencoder',
#                                                                    OneHotEnc...
#                  SelectKBest(k=35,
#                              score_func=<function f_classif at 0x0000025177BFCE58>)),
#                 ('logistic',
#                  LogisticRegression(C=1.0,
#                                     class_weight={False: 25000, True: 280000},
#                                     dual=False, fit_intercept=True,
#                                     intercept_scaling=1, l1_ratio=None,
#                                     max_iter=350, multi_class='auto',
#                                     n_jobs=None, penalty='l2', random_state=42,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %% [markdown]
# param_grid = {'model_ada__n_estimators':[250],
#              }
# grid_search = GridSearchCV(estimator=classifier,
#                            param_grid=param_grid,
#                            scoring=ftwo_scorer,
#                            cv=2,
#                            verbose=1,
#                            n_jobs=-1)

# %%
X_resample = pd.DataFrame(X_resample,columns=feat_names)

# %% [markdown]
# #grid_search.fit(X_resample, y_resample)
# #cv_score = classifier.score(X_train,y_train)
# #cv_score = grid_search.best_score_
# #ftwo_scorer(y_test,pipeline.predict(X_test))
# test_score = grid_search.score(X_test, y_test)
#
# print(f'Cross-validation score: {cv_score} \nTest score: {test_score}')

# %%
classifier.fit(X_resample, y_resample)
cv_score_1 = classifier.score(X_resample,y_resample)
print(cv_score_1)
# Out:
# 0.6588872870712681

# %%
cross_val_score(classifier, X_resample, y_resample, scoring=ftwo_scorer, cv= 4, n_jobs=-1 )
# Out:
# array([0.55091809, 0.82828184, 0.82091897, 0.82242698])

# %%
y_pred = cross_val_predict(classifier,X_test,y_test,cv=5,n_jobs=-1)
print(fbeta_score(y_test,y_pred,beta=2,pos_label=True))
print(accuracy_score(y_test,y_pred))
# Out:
# 0.4004627350595648
# 0.6866331723655756

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.96      0.69      0.80     56554
#         True       0.16      0.66      0.25      4949
#
#     accuracy                           0.69     61503
#    macro avg       0.56      0.67      0.53     61503
# weighted avg       0.89      0.69      0.76     61503

# %%
(pd.crosstab(index=y_test, columns=y_pred, normalize="index")
         .pipe((sns.heatmap, "data"), vmin=0, vmax=1, cmap="Greens", cbar=True,
               annot=True, square=False, fmt=".2f", ax=None)
         )
# Out:
# <AxesSubplot:xlabel='col_0', ylabel='TARGET'>

# %%
joblib.dump(classifier, "logistic_reg_tuned.pkl")
# Out:
# ['logistic_reg_tuned.pkl']

# %% [markdown]
# from sklearn.metrics import accuracy_score,f1_score
# y_pred = classifier.predict(X_test.loc[:,X_resample.columns])
# print(fbeta_score(y_test,y_pred,beta=2,pos_label=True))
# print(f1_score(y_test,y_pred))
# print(accuracy_score(y_test,y_pred))

# %% [markdown]
# Adaboost = 0.67 / 15 min d'execution
#
# le meilleur résultat est avec adaboost pour un n_estimators de 200 , résultat de 0.92

# %% [markdown]
# from xgboost import plot_importance
# plot_importance(classifier.named_steps['model_xgb'])
# plt.show()

# %% [markdown]
# X_resample

# %% [markdown]
# grid_search.best_params_

# %% [markdown]
# # X_test_prep,y_test_prep = grid_search.fit_transform(X_test,y_test)
# # y_pred = grid_search.predict(X_test_prep)
# # print(classification_report(y_test, y_pred))

# %% [markdown]
# bestimator = grid_search.best_estimator_
# y_pred = bestimator.predict(X_test)
# test_score = grid_search.score(X_test, y_test)
